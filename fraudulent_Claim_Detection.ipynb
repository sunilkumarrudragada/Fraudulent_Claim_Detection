# %% [markdown]
# ## **Fraudulent Claim Detection**

# %% [markdown]
# ## Problem Statement
# Global Insure, a leading insurance company, processes thousands of claims annually. However, a significant percentage of these claims turn out to be fraudulent, resulting in considerable financial losses. The company’s current process for identifying fraudulent claims involves manual inspections, which is time-consuming and inefficient. Fraudulent claims are often detected too late in the process, after the company has already paid out significant amounts. Global Insure wants to improve its fraud detection process using data-driven insights to classify claims as fraudulent or legitimate early in the approval process. This would minimise financial losses and optimise the overall claims handling process.
#
# ## Business Objective
# Global Insure wants to build a model to classify insurance claims as either fraudulent or legitimate based on historical claim details and customer profiles. By using features like claim amounts, customer profiles and claim types, the company aims to predict which claims are likely to be fraudulent before they are approved.
#
#
# Based on this assignment, you have to answer the following questions:<br>
#
# ● How can we analyse historical claim data to detect patterns that indicate fraudulent claims?<br>
# ● Which features are most predictive of fraudulent behaviour?<br>
# ● Can we predict the likelihood of fraud for an incoming claim, based on past data?<br>
# ● What insights can be drawn from the model that can help in improving the fraud detection process?<br>

# %% [markdown]
# ## Assignment Tasks
# You need to perform the following steps for successfully completing this assignment:
# 1. Data Preparation
# 2. Data Cleaning
# 3. Train Validation Split 70-30
# 4. EDA on Training Data
# 5. EDA on Validation Data (optional)
# 6. Feature Engineering
# 7. Model Building
# 8. Predicting and Model Evaluation

# %%
# policy_number, policy_bind_date, policy_state, insured_zip, incident_state, incident_location, incident_country, auto_make, auto_model, auto_year, incident_date, incident_city, insured_hobbies

# %% [markdown]
# ## Data Dictionary
# The insurance claims data has 40 Columns and 1000 Rows. Following data dictionary provides the description for each column present in dataset:<br>
#
# <table>
#   <thead>
#     <tr>
#       <th>Column Name</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>months_as_customer</td>
#       <td>Represents the duration in months that a customer has been associated with the insurance company.</td>
#     </tr>
#     <tr>
#       <td>age</td>
#       <td>Represents the age of the insured person.</td>
#     </tr>
#     <tr>
#       <td>policy_number</td>
#       <td>Represents a unique identifier for each insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_bind_date</td>
#       <td>Represents the date when the insurance policy was initiated.</td>
#     </tr>
#     <tr>
#       <td>policy_state</td>
#       <td>Represents the state where the insurance policy is applicable.</td>
#     </tr>
#     <tr>
#       <td>policy_csl</td>
#       <td>Represents the combined single limit for the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_deductable</td>
#       <td>Represents the amount that the insured person needs to pay before the insurance coverage kicks in.</td>
#     </tr>
#     <tr>
#       <td>policy_annual_premium</td>
#       <td>Represents the yearly cost of the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>umbrella_limit</td>
#       <td>Represents an additional layer of liability coverage provided beyond the limits of the primary insurance policy.</td>
#     </tr>
#     <tr>
#       <td>insured_zip</td>
#       <td>Represents the zip code of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_sex</td>
#       <td>Represents the gender of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_education_level</td>
#       <td>Represents the highest educational qualification of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_occupation</td>
#       <td>Represents the profession or job of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_hobbies</td>
#       <td>Represents the hobbies or leisure activities of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_relationship</td>
#       <td>Represents the relationship of the insured person to the policyholder.</td>
#     </tr>
#     <tr>
#       <td>capital-gains</td>
#       <td>Represents the profit earned from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>capital-loss</td>
#       <td>Represents the loss incurred from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>incident_date</td>
#       <td>Represents the date when the incident or accident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_type</td>
#       <td>Represents the category or type of incident that led to the claim.</td>
#     </tr>
#     <tr>
#       <td>collision_type</td>
#       <td>Represents the type of collision that occurred in an accident.</td>
#     </tr>
#     <tr>
#       <td>incident_severity</td>
#       <td>Represents the extent of damage or injury caused by the incident.</td>
#     </tr>
#     <tr>
#       <td>authorities_contacted</td>
#       <td>Represents the authorities or agencies that were contacted after the incident.</td>
#     </tr>
#     <tr>
#       <td>incident_state</td>
#       <td>Represents the state where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_city</td>
#       <td>Represents the city where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_location</td>
#       <td>Represents the specific location or address where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_hour_of_the_day</td>
#       <td>Represents the hour of the day when the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>number_of_vehicles_involved</td>
#       <td>Represents the total number of vehicles involved in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_damage</td>
#       <td>Represents whether there was any damage to property in the incident.</td>
#     </tr>
#     <tr>
#       <td>bodily_injuries</td>
#       <td>Represents the number of bodily injuries resulting from the incident.</td>
#     </tr>
#     <tr>
#       <td>witnesses</td>
#       <td>Represents the number of witnesses present at the scene of the incident.</td>
#     </tr>
#     <tr>
#       <td>police_report_available</td>
#       <td>Represents whether a police report is available for the incident.</td>
#     </tr>
#     <tr>
#       <td>total_claim_amount</td>
#       <td>Represents the total amount claimed by the insured person for the incident.</td>
#     </tr>
#     <tr>
#       <td>injury_claim</td>
#       <td>Represents the amount claimed for injuries sustained in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_claim</td>
#       <td>Represents the amount claimed for property damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>vehicle_claim</td>
#       <td>Represents the amount claimed for vehicle damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>auto_make</td>
#       <td>Represents the manufacturer of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_model</td>
#       <td>Represents the specific model of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_year</td>
#       <td>Represents the year of manufacture of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>fraud_reported</td>
#       <td>Represents whether the claim was reported as fraudulent or not.</td>
#     </tr>
#     <tr>
#       <td>_c39</td>
#       <td>Represents an unknown or unspecified variable.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **1. Data Preparation**
# In this step, read the dataset provided in CSV format and look at basic statistics of the data, including preview of data, dimension of data, column descriptions and data types.

# %% [markdown]
# ### **1.0 Import Libraries**

# %%
# Supress unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### **1.1 Load the Data**

# %%
# Load the dataset
df=pd.read_csv('insurance_claims.csv')

# %%
# Check at the first few entries
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# 0       466132        MALE                      MD       craft-repair
# 1       468176        MALE                      MD  machine-op-inspct
# 2       430632      FEMALE                     PhD              sales
# 3       608117      FEMALE                     PhD       armed-forces
# 4       610706        MALE               Associate              sales
#
#   insured_hobbies insured_relationship  capital-gains  capital-loss  \
# 0        sleeping              husband          53300             0
# 1         reading       other-relative              0             0
# 2     board-games            own-child          35100             0
# 3     board-games            unmarried          48900        -62400
# 4     board-games            unmarried          66000        -46000
#
#   incident_date             incident_type   collision_type incident_severity  \
# 0    2015-01-25  Single Vehicle Collision   Side Collision      Major Damage
# 1    2015-01-21             Vehicle Theft                ?      Minor Damage
# 2    2015-02-22   Multi-vehicle Collision   Rear Collision      Minor Damage
# 3    2015-01-10  Single Vehicle Collision  Front Collision      Major Damage
# 4    2015-02-17             Vehicle Theft                ?      Minor Damage
#
#   authorities_contacted incident_state incident_city  incident_location  \
# 0                Police             SC      Columbus     9935 4th Drive
# 1                Police             VA     Riverwood       6608 MLK Hwy
# 2                Police             NY      Columbus  7121 Francis Lane
# 3                Police             OH     Arlington   6956 Maple Drive
# 4                   NaN             NY     Arlington       3041 3rd Ave
#
#    incident_hour_of_the_day  number_of_vehicles_involved property_damage  \
# 0                         5                            1             YES
# 1                         8                            1               ?
# 2                         7                            3              NO
# 3                         5                            1               ?
# 4                        20                            1              NO
#
#    bodily_injuries  witnesses police_report_available  total_claim_amount  \
# 0                1          2                     YES               71610
# 1                0          0                       ?                5070
# 2                2          3                      NO               34650
# 3                1          2                      NO               63400
# 4                0          1                      NO                6500
#
#    injury_claim  property_claim  vehicle_claim  auto_make auto_model  \
# 0          6510           13020          52080       Saab        92x
# 1           780             780           3510   Mercedes       E400
# 2          7700            3850          23100      Dodge        RAM
# 3          6340            6340          50720  Chevrolet      Tahoe
# 4          1300             650           4550     Accura        RSX
#
#    auto_year fraud_reported  _c39
# 0       2004              Y   NaN
# 1       2007              Y   NaN
# 2       2007              N   NaN
# 3       2014              Y   NaN
# 4       2009              N   NaN

# %%
# Inspect the shape of the dataset
df.shape
# Out:
# (1000, 40)

# %%
# Inspect the features in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
#  13  insured_hobbies              1000 non-null   object
#  14  insured_relationship         1000 non-null   object
#  15  capital-gains                1000 non-null   int64
#  16  capital-loss                 1000 non-null   int64
#  17  incident_date                1000 non-null   object
#  18  incident_type                1000 non-null   object
#  19  collision_type               1000 non-null   object
#  20  incident_severity            1000 non-null   object
#  21  authorities_contacted        909 non-null    object
#  22  incident_state               1000 non-null   object
#  23  incident_city                1000 non-null   object
#  24  incident_location            1000 non-null   object
#  25  incident_hour_of_the_day     1000 non-null   int64
#  26  number_of_vehicles_involved  1000 non-null   int64
#  27  property_damage              1000 non-null   object
#  28  bodily_injuries              1000 non-null   int64
#  29  witnesses                    1000 non-null   int64
#  30  police_report_available      1000 non-null   object
#  31  total_claim_amount           1000 non-null   int64
#  32  injury_claim                 1000 non-null   int64
#  33  property_claim               1000 non-null   int64
#  34  vehicle_claim                1000 non-null   int64
#  35  auto_make                    1000 non-null   object
#  36  auto_model                   1000 non-null   object
#  37  auto_year                    1000 non-null   int64
#  38  fraud_reported               1000 non-null   object
#  39  _c39                         0 non-null      float64
# dtypes: float64(2), int64(17), object(21)
# memory usage: 312.6+ KB

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# min               433.330000   -1.000000e+06  430104.000000       0.000000
# 25%              1089.607500    0.000000e+00  448404.500000       0.000000
# 50%              1257.200000    0.000000e+00  466445.500000       0.000000
# 75%              1415.695000    0.000000e+00  603251.000000   51025.000000
# max              2047.590000    1.000000e+07  620962.000000  100500.000000
#
#         capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# count    1000.000000               1000.000000                   1000.00000
# mean   -26793.700000                 11.644000                      1.83900
# std     28104.096686                  6.951373                      1.01888
# min   -111100.000000                  0.000000                      1.00000
# 25%    -51500.000000                  6.000000                      1.00000
# 50%    -23250.000000                 12.000000                      1.00000
# 75%         0.000000                 17.000000                      3.00000
# max         0.000000                 23.000000                      4.00000
#
#        bodily_injuries    witnesses  total_claim_amount  injury_claim  \
# count      1000.000000  1000.000000          1000.00000   1000.000000
# mean          0.992000     1.487000         52761.94000   7433.420000
# std           0.820127     1.111335         26401.53319   4880.951853
# min           0.000000     0.000000           100.00000      0.000000
# 25%           0.000000     1.000000         41812.50000   4295.000000
# 50%           1.000000     1.000000         58055.00000   6775.000000
# 75%           2.000000     2.000000         70592.50000  11305.000000
# max           2.000000     3.000000        114920.00000  21450.000000
#
#        property_claim  vehicle_claim    auto_year  _c39
# count     1000.000000    1000.000000  1000.000000   0.0
# mean      7399.570000   37928.950000  2005.103000   NaN
# std       4824.726179   18886.252893     6.015861   NaN
# min          0.000000      70.000000  1995.000000   NaN
# 25%       4445.000000   30292.500000  2000.000000   NaN
# 50%       6750.000000   42100.000000  2005.000000   NaN
# 75%      10885.000000   50822.500000  2010.000000   NaN
# max      23670.000000   79560.000000  2015.000000   NaN

# %% [markdown]
# ## **2. Data Cleaning** <font color = red>[10 marks]</font>

# %% [markdown]
# ### **2.1 Handle null values** <font color = red>[2 marks]</font>

# %% [markdown]
# #### **2.1.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[1 Mark]</font>

# %%
# Check the number of missing values in each column
df.isna().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                   0
# bodily_injuries                   0
# witnesses                         0
# police_report_available           0
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# dtype: int64

# %% [markdown]
# #### **2.1.2** Handle rows containing null values <font color="red">[1 Mark]</font>

# %%
# Handle the rows containing null values
print('Percentage of na values for authorities_contacted is',(df['authorities_contacted'].isna().sum()/len(df))*100)
# Out:
# Percentage of na values for authorities_contacted is 9.1

# %%
# As the percentage is 9.1 it is better to consider na value as unknown which might be useful in analysis
# Impute with Unknown

df['authorities_contacted']=df['authorities_contacted'].fillna('Unknown')

# %%
df['authorities_contacted'].head()
# Out:
# 0     Police
# 1     Police
# 2     Police
# 3     Police
# 4    Unknown
# Name: authorities_contacted, dtype: object

# %% [markdown]
# ### **2.2 Identify and handle redundant values and columns** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **2.2.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[2 Mark]</font>

# %%
# Write code to display all the columns with their unique values and counts and check for redundant values
for col in df.columns:
    print(f"\nColumn: {col}")
    print("-" * (9 + len(col)))
    print(df[col].value_counts(dropna=False))  # dropna=False to include NaN counts
    print(f"\nUnique values count: {df[col].nunique(dropna=False)}")
# Out:
# Column: months_as_customer
# ---------------------------
# months_as_customer
# 194    8
# 128    7
# 254    7
# 140    7
# 210    7
#       ..
# 390    1
# 411    1
# 453    1
# 448    1
# 17     1
# Name: count, Length: 391, dtype: int64
#
# Unique values count: 391
#
# Column: age
# ------------
# age
# 43    49
# 39    48
# 41    45
# 34    44
# 38    42
# 30    42
# 31    42
# 37    41
# 33    39
# 40    38
# 32    38
# 29    35
# 46    33
# 42    32
# 35    32
# 36    32
# 44    32
# 28    30
# 26    26
# 45    26
# 48    25
# 47    24
# 27    24
# 57    16
# 25    14
# 55    14
# 49    14
# 53    13
# 50    13
# 24    10
# 54    10
# 61    10
# 51     9
# 60     9
# 58     8
# 56     8
# 23     7
# 21     6
# 59     5
# 62     4
# 52     4
# 64     2
# 63     2
# 19     1
# 20     1
# 22     1
# Name: count, dtype: int64
#
# Unique values count: 46
#
# Column: policy_number
# ----------------------
# policy_number
# 521585    1
# 687755    1
# 674485    1
# 223404    1
# 991480    1
#          ..
# 563878    1
# 620855    1
# 583169    1
# 337677    1
# 556080    1
# Name: count, Length: 1000, dtype: int64
#
# Unique values count: 1000
#
# Column: policy_bind_date
# -------------------------
# policy_bind_date
# 2006-01-01    3
# 1992-04-28    3
# 1992-08-05    3
# 1991-12-14    2
# 2004-08-09    2
#              ..
# 2014-06-03    1
# 1998-12-12    1
# 1999-02-18    1
# 1997-10-30    1
# 1996-11-11    1
# Name: count, Length: 951, dtype: int64
#
# Unique values count: 951
#
# Column: policy_state
# ---------------------
# policy_state
# OH    352
# IL    338
# IN    310
# Name: count, dtype: int64
#
# Unique values count: 3
#
# Column: policy_csl
# -------------------
# policy_csl
# 250/500     351
# 100/300     349
# 500/1000    300
# Name: count, dtype: int64
#
# Unique values count: 3
#
# Column: policy_deductable
# --------------------------
# policy_deductable
# 1000    351
# 500     342
# 2000    307
# Name: count, dtype: int64
#
# Unique values count: 3
#
# Column: policy_annual_premium
# ------------------------------
# policy_annual_premium
# 1558.29    2
# 1215.36    2
# 1362.87    2
# 1073.83    2
# 1389.13    2
#           ..
# 1085.03    1
# 1437.33    1
# 988.29     1
# 1238.89    1
# 766.19     1
# Name: count, Length: 991, dtype: int64
#
# Unique values count: 991
#
# Column: umbrella_limit
# -----------------------
# umbrella_limit
#  0           798
#  6000000      57
#  5000000      46
#  4000000      39
#  7000000      29
#  3000000      12
#  8000000       8
#  9000000       5
#  2000000       3
#  10000000      2
# -1000000       1
# Name: count, dtype: int64
#
# Unique values count: 11
#
# Column: insured_zip
# --------------------
# insured_zip
# 477695    2
# 469429    2
# 446895    2
# 431202    2
# 456602    2
#          ..
# 476303    1
# 450339    1
# 476502    1
# 600561    1
# 612260    1
# Name: count, Length: 995, dtype: int64
#
# Unique values count: 995
#
# Column: insured_sex
# --------------------
# insured_sex
# FEMALE    537
# MALE      463
# Name: count, dtype: int64
#
# Unique values count: 2
#
# Column: insured_education_level
# --------------------------------
# insured_education_level
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: count, dtype: int64
#
# Unique values count: 7
#
# Column: insured_occupation
# ---------------------------
# insured_occupation
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# sales                76
# exec-managerial      76
# craft-repair         74
# transport-moving     72
# other-service        71
# priv-house-serv      71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: count, dtype: int64
#
# Unique values count: 14
#
# Column: insured_hobbies
# ------------------------
# insured_hobbies
# reading           64
# exercise          57
# paintball         57
# bungie-jumping    56
# movies            55
# golf              55
# camping           55
# kayaking          54
# yachting          53
# hiking            52
# video-games       50
# skydiving         49
# base-jumping      49
# board-games       48
# polo              47
# chess             46
# dancing           43
# sleeping          41
# cross-fit         35
# basketball        34
# Name: count, dtype: int64
#
# Unique values count: 20
#
# Column: insured_relationship
# -----------------------------
# insured_relationship
# own-child         183
# other-relative    177
# not-in-family     174
# husband           170
# wife              155
# unmarried         141
# Name: count, dtype: int64
#
# Unique values count: 6
#
# Column: capital-gains
# ----------------------
# capital-gains
# 0        508
# 46300      5
# 51500      4
# 68500      4
# 55600      3
#         ...
# 36700      1
# 54900      1
# 69200      1
# 48800      1
# 50300      1
# Name: count, Length: 338, dtype: int64
#
# Unique values count: 338
#
# Column: capital-loss
# ---------------------
# capital-loss
#  0        475
# -31700      5
# -53700      5
# -50300      5
# -45300      4
#          ...
# -12100      1
# -17000      1
# -72900      1
# -19700      1
# -82100      1
# Name: count, Length: 354, dtype: int64
#
# Unique values count: 354
#
# Column: incident_date
# ----------------------
# incident_date
# 2015-02-02    28
# 2015-02-17    26
# 2015-01-07    25
# 2015-01-10    24
# 2015-02-04    24
# 2015-01-24    24
# 2015-01-19    23
# 2015-01-08    22
# 2015-01-13    21
# 2015-01-30    21
# 2015-02-12    20
# 2015-02-22    20
# 2015-01-31    20
# 2015-02-06    20
# 2015-02-21    19
# 2015-01-01    19
# 2015-02-23    19
# 2015-01-12    19
# 2015-01-14    19
# 2015-01-21    19
# 2015-01-03    18
# 2015-02-14    18
# 2015-02-01    18
# 2015-02-28    18
# 2015-01-20    18
# 2015-01-18    18
# 2015-02-25    18
# 2015-01-06    17
# 2015-01-09    17
# 2015-02-08    17
# 2015-02-24    17
# 2015-02-26    17
# 2015-02-13    16
# 2015-02-15    16
# 2015-02-16    16
# 2015-02-05    16
# 2015-01-16    16
# 2015-01-17    15
# 2015-02-18    15
# 2015-01-28    15
# 2015-01-15    15
# 2015-01-22    14
# 2015-02-20    14
# 2015-02-27    14
# 2015-01-23    13
# 2015-02-03    13
# 2015-01-27    13
# 2015-02-09    13
# 2015-01-04    12
# 2015-03-01    12
# 2015-01-26    11
# 2015-01-29    11
# 2015-01-02    11
# 2015-02-19    10
# 2015-02-11    10
# 2015-02-10    10
# 2015-02-07    10
# 2015-01-25    10
# 2015-01-11     9
# 2015-01-05     7
# Name: count, dtype: int64
#
# Unique values count: 60
#
# Column: incident_type
# ----------------------
# incident_type
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: count, dtype: int64
#
# Unique values count: 4
#
# Column: collision_type
# -----------------------
# collision_type
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# ?                  178
# Name: count, dtype: int64
#
# Unique values count: 4
#
# Column: incident_severity
# --------------------------
# incident_severity
# Minor Damage      354
# Total Loss        280
# Major Damage      276
# Trivial Damage     90
# Name: count, dtype: int64
#
# Unique values count: 4
#
# Column: authorities_contacted
# ------------------------------
# authorities_contacted
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# Unknown       91
# Name: count, dtype: int64
#
# Unique values count: 5
#
# Column: incident_state
# -----------------------
# incident_state
# NY    262
# SC    248
# WV    217
# VA    110
# NC    110
# PA     30
# OH     23
# Name: count, dtype: int64
#
# Unique values count: 7
#
# Column: incident_city
# ----------------------
# incident_city
# Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: count, dtype: int64
#
# Unique values count: 7
#
# Column: incident_location
# --------------------------
# incident_location
# 9935 4th Drive         1
# 4214 MLK Ridge         1
# 8548 Cherokee Ridge    1
# 2352 MLK Drive         1
# 9734 2nd Ridge         1
#                       ..
# 6770 1st St            1
# 4119 Texas St          1
# 4347 2nd Ridge         1
# 1091 1st Drive         1
# 1416 Cherokee Ridge    1
# Name: count, Length: 1000, dtype: int64
#
# Unique values count: 1000
#
# Column: incident_hour_of_the_day
# ---------------------------------
# incident_hour_of_the_day
# 17    54
# 3     53
# 0     52
# 23    51
# 16    49
# 13    46
# 10    46
# 4     46
# 6     44
# 9     43
# 14    43
# 21    42
# 18    41
# 12    40
# 19    40
# 7     40
# 15    39
# 22    38
# 8     36
# 20    34
# 5     33
# 2     31
# 11    30
# 1     29
# Name: count, dtype: int64
#
# Unique values count: 24
#
# Column: number_of_vehicles_involved
# ------------------------------------
# number_of_vehicles_involved
# 1    581
# 3    358
# 4     31
# 2     30
# Name: count, dtype: int64
#
# Unique values count: 4
#
# Column: property_damage
# ------------------------
# property_damage
# ?      360
# NO     338
# YES    302
# Name: count, dtype: int64
#
# Unique values count: 3
#
# Column: bodily_injuries
# ------------------------
# bodily_injuries
# 0    340
# 2    332
# 1    328
# Name: count, dtype: int64
#
# Unique values count: 3
#
# Column: witnesses
# ------------------
# witnesses
# 1    258
# 2    250
# 0    249
# 3    243
# Name: count, dtype: int64
#
# Unique values count: 4
#
# Column: police_report_available
# --------------------------------
# police_report_available
# ?      343
# NO     343
# YES    314
# Name: count, dtype: int64
#
# Unique values count: 3
#
# Column: total_claim_amount
# ---------------------------
# total_claim_amount
# 59400    5
# 2640     4
# 70400    4
# 4320     4
# 44200    4
#         ..
# 65250    1
# 87100    1
# 6240     1
# 66600    1
# 67500    1
# Name: count, Length: 763, dtype: int64
#
# Unique values count: 763
#
# Column: injury_claim
# ---------------------
# injury_claim
# 0        25
# 640       7
# 480       7
# 660       5
# 580       5
#          ..
# 14840     1
# 6580      1
# 11820     1
# 16650     1
# 7500      1
# Name: count, Length: 638, dtype: int64
#
# Unique values count: 638
#
# Column: property_claim
# -----------------------
# property_claim
# 0        19
# 860       6
# 480       5
# 660       5
# 10000     5
#          ..
# 3590      1
# 6480      1
# 4580      1
# 4920      1
# 7500      1
# Name: count, Length: 626, dtype: int64
#
# Unique values count: 626
#
# Column: vehicle_claim
# ----------------------
# vehicle_claim
# 5040     7
# 3360     6
# 52080    5
# 4720     5
# 3600     5
#         ..
# 43360    1
# 25130    1
# 38940    1
# 47430    1
# 52500    1
# Name: count, Length: 726, dtype: int64
#
# Unique values count: 726
#
# Column: auto_make
# ------------------
# auto_make
# Saab          80
# Dodge         80
# Suburu        80
# Nissan        78
# Chevrolet     76
# Ford          72
# BMW           72
# Toyota        70
# Audi          69
# Accura        68
# Volkswagen    68
# Jeep          67
# Mercedes      65
# Honda         55
# Name: count, dtype: int64
#
# Unique values count: 14
#
# Column: auto_model
# -------------------
# auto_model
# RAM               43
# Wrangler          42
# A3                37
# Neon              37
# MDX               36
# Jetta             35
# Passat            33
# A5                32
# Legacy            32
# Pathfinder        31
# Malibu            30
# 92x               28
# Camry             28
# Forrestor         28
# F150              27
# 95                27
# E400              27
# 93                25
# Grand Cherokee    25
# Escape            24
# Tahoe             24
# Maxima            24
# Ultima            23
# X5                23
# Highlander        22
# Civic             22
# Silverado         22
# Fusion            21
# ML350             20
# Impreza           20
# Corolla           20
# TL                20
# CRV               20
# C300              18
# 3 Series          18
# X6                16
# M5                15
# Accord            13
# RSX               12
# Name: count, dtype: int64
#
# Unique values count: 39
#
# Column: auto_year
# ------------------
# auto_year
# 1995    56
# 1999    55
# 2005    54
# 2006    53
# 2011    53
# 2007    52
# 2003    51
# 2009    50
# 2010    50
# 2013    49
# 2002    49
# 2015    47
# 1997    46
# 2012    46
# 2008    45
# 2014    44
# 2001    42
# 2000    42
# 1998    40
# 2004    39
# 1996    37
# Name: count, dtype: int64
#
# Unique values count: 21
#
# Column: fraud_reported
# -----------------------
# fraud_reported
# N    753
# Y    247
# Name: count, dtype: int64
#
# Unique values count: 2
#
# Column: _c39
# -------------
# _c39
# NaN    1000
# Name: count, dtype: int64
#
# Unique values count: 1

# %%
# to view no.of unique values present in each column
df.nunique()
# Out:
# months_as_customer              391
# age                              46
# policy_number                  1000
# policy_bind_date                951
# policy_state                      3
# policy_csl                        3
# policy_deductable                 3
# policy_annual_premium           991
# umbrella_limit                   11
# insured_zip                     995
# insured_sex                       2
# insured_education_level           7
# insured_occupation               14
# insured_hobbies                  20
# insured_relationship              6
# capital-gains                   338
# capital-loss                    354
# incident_date                    60
# incident_type                     4
# collision_type                    4
# incident_severity                 4
# authorities_contacted             5
# incident_state                    7
# incident_city                     7
# incident_location              1000
# incident_hour_of_the_day         24
# number_of_vehicles_involved       4
# property_damage                   3
# bodily_injuries                   3
# witnesses                         4
# police_report_available           3
# total_claim_amount              763
# injury_claim                    638
# property_claim                  626
# vehicle_claim                   726
# auto_make                        14
# auto_model                       39
# auto_year                        21
# fraud_reported                    2
# _c39                              0
# dtype: int64

# %%
# There are some columns which are having question mark as the value
columns_with_exact_question_mark=[]
for col in df.columns:
    if (df[col]=='?').any():
        columns_with_exact_question_mark.append(col)

print('columns with exact question mark values:', columns_with_exact_question_mark)
# Out:
# columns with exact question mark values: ['collision_type', 'property_damage', 'police_report_available']

# %%
# impute the columns_with_exact_question_mark with Unknown value
df[columns_with_exact_question_mark]=df[columns_with_exact_question_mark].replace('?', 'Unknown')

# %%
df[columns_with_exact_question_mark].head()
# Out:
#     collision_type property_damage police_report_available
# 0   Side Collision             YES                     YES
# 1          Unknown         Unknown                 Unknown
# 2   Rear Collision              NO                      NO
# 3  Front Collision         Unknown                      NO
# 4          Unknown              NO                      NO

# %% [markdown]
# #### **2.2.2** Identify and drop any columns that are completely empty <font color="red">[1 Mark]</font>

# %%
# Identify and drop any columns that are completely empty
df.drop(['_c39'], axis=1, inplace=True)

# %%
print('Shape of the dataframe after dropping the _c39 column: ', df.shape)
# Out:
# Shape of the dataframe after dropping the _c39 column:  (1000, 39)

# %% [markdown]
# #### **2.2.3** Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values <font color="red">[1 Mark]</font>

# %%
# Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values
numerical_cols=df.select_dtypes(include='number').columns
print('numerical columns are: ',numerical_cols)

for col in numerical_cols:
    negative_count=(df[col] < 0).sum()
    if negative_count > 0:
        print(col,': ', negative_count)
# Out:
# numerical columns are:  Index(['months_as_customer', 'age', 'policy_number', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip',
#        'capital-gains', 'capital-loss', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'bodily_injuries', 'witnesses',
#        'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim',
#        'auto_year'],
#       dtype='object')
# umbrella_limit :  1
# capital-loss :  525

# %%
df=df[df['umbrella_limit'] >=0]
print('shape of data frame after removing negative values in umbrella_limit column: ', df.shape)
# Out:
# shape of data frame after removing negative values in umbrella_limit column:  (999, 39)

# %%
for col in numerical_cols:
    negative_count=(df[col] < 0).sum()
    if negative_count > 0:
        print(col,': ', negative_count)
# Out:
# capital-loss :  525

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# 0       466132        MALE                      MD       craft-repair
# 1       468176        MALE                      MD  machine-op-inspct
# 2       430632      FEMALE                     PhD              sales
# 3       608117      FEMALE                     PhD       armed-forces
# 4       610706        MALE               Associate              sales
#
#   insured_hobbies insured_relationship  capital-gains  capital-loss  \
# 0        sleeping              husband          53300             0
# 1         reading       other-relative              0             0
# 2     board-games            own-child          35100             0
# 3     board-games            unmarried          48900        -62400
# 4     board-games            unmarried          66000        -46000
#
#   incident_date             incident_type   collision_type incident_severity  \
# 0    2015-01-25  Single Vehicle Collision   Side Collision      Major Damage
# 1    2015-01-21             Vehicle Theft          Unknown      Minor Damage
# 2    2015-02-22   Multi-vehicle Collision   Rear Collision      Minor Damage
# 3    2015-01-10  Single Vehicle Collision  Front Collision      Major Damage
# 4    2015-02-17             Vehicle Theft          Unknown      Minor Damage
#
#   authorities_contacted incident_state incident_city  incident_location  \
# 0                Police             SC      Columbus     9935 4th Drive
# 1                Police             VA     Riverwood       6608 MLK Hwy
# 2                Police             NY      Columbus  7121 Francis Lane
# 3                Police             OH     Arlington   6956 Maple Drive
# 4               Unknown             NY     Arlington       3041 3rd Ave
#
#    incident_hour_of_the_day  number_of_vehicles_involved property_damage  \
# 0                         5                            1             YES
# 1                         8                            1         Unknown
# 2                         7                            3              NO
# 3                         5                            1         Unknown
# 4                        20                            1              NO
#
#    bodily_injuries  witnesses police_report_available  total_claim_amount  \
# 0                1          2                     YES               71610
# 1                0          0                 Unknown                5070
# 2                2          3                      NO               34650
# 3                1          2                      NO               63400
# 4                0          1                      NO                6500
#
#    injury_claim  property_claim  vehicle_claim  auto_make auto_model  \
# 0          6510           13020          52080       Saab        92x
# 1           780             780           3510   Mercedes       E400
# 2          7700            3850          23100      Dodge        RAM
# 3          6340            6340          50720  Chevrolet      Tahoe
# 4          1300             650           4550     Accura        RSX
#
#    auto_year fraud_reported
# 0       2004              Y
# 1       2007              Y
# 2       2007              N
# 3       2014              Y
# 4       2009              N

# %% [markdown]
# #### **2.2.4** Identify and remove columns where a large proportion of the values are unique or near-unique, as these columns are likely to be identifiers or have very limited predictive power <font color="red">[1 Mark]</font>

# %%
# Identify and remove columns that are likely to be identifiers or have very limited predictive power
coumns_to_drop = ['policy_number','policy_bind_date','policy_state','insured_zip','incident_location', 'incident_state','incident_city','insured_hobbies','auto_make','auto_model','auto_year']
df.drop(coumns_to_drop, axis=1, inplace=True)

# %%
# Check the dataset
print('Shape of the dataframe after dropping the unneccessary columns: ', df.shape)
# Out:
# Shape of the dataframe after dropping the unneccessary columns:  (999, 28)

# %%
df.head()
# Out:
#    months_as_customer  age policy_csl  policy_deductable  \
# 0                 328   48    250/500               1000
# 1                 228   42    250/500               2000
# 2                 134   29    100/300               2000
# 3                 256   41    250/500               2000
# 4                 228   44   500/1000               1000
#
#    policy_annual_premium  umbrella_limit insured_sex insured_education_level  \
# 0                1406.91               0        MALE                      MD
# 1                1197.22         5000000        MALE                      MD
# 2                1413.14         5000000      FEMALE                     PhD
# 3                1415.74         6000000      FEMALE                     PhD
# 4                1583.91         6000000        MALE               Associate
#
#   insured_occupation insured_relationship  capital-gains  capital-loss  \
# 0       craft-repair              husband          53300             0
# 1  machine-op-inspct       other-relative              0             0
# 2              sales            own-child          35100             0
# 3       armed-forces            unmarried          48900        -62400
# 4              sales            unmarried          66000        -46000
#
#   incident_date             incident_type   collision_type incident_severity  \
# 0    2015-01-25  Single Vehicle Collision   Side Collision      Major Damage
# 1    2015-01-21             Vehicle Theft          Unknown      Minor Damage
# 2    2015-02-22   Multi-vehicle Collision   Rear Collision      Minor Damage
# 3    2015-01-10  Single Vehicle Collision  Front Collision      Major Damage
# 4    2015-02-17             Vehicle Theft          Unknown      Minor Damage
#
#   authorities_contacted  incident_hour_of_the_day  \
# 0                Police                         5
# 1                Police                         8
# 2                Police                         7
# 3                Police                         5
# 4               Unknown                        20
#
#    number_of_vehicles_involved property_damage  bodily_injuries  witnesses  \
# 0                            1             YES                1          2
# 1                            1         Unknown                0          0
# 2                            3              NO                2          3
# 3                            1         Unknown                1          2
# 4                            1              NO                0          1
#
#   police_report_available  total_claim_amount  injury_claim  property_claim  \
# 0                     YES               71610          6510           13020
# 1                 Unknown                5070           780             780
# 2                      NO               34650          7700            3850
# 3                      NO               63400          6340            6340
# 4                      NO                6500          1300             650
#
#    vehicle_claim fraud_reported
# 0          52080              Y
# 1           3510              Y
# 2          23100              N
# 3          50720              Y
# 4           4550              N

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, 0 to 999
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           999 non-null    int64
#  1   age                          999 non-null    int64
#  2   policy_csl                   999 non-null    object
#  3   policy_deductable            999 non-null    int64
#  4   policy_annual_premium        999 non-null    float64
#  5   umbrella_limit               999 non-null    int64
#  6   insured_sex                  999 non-null    object
#  7   insured_education_level      999 non-null    object
#  8   insured_occupation           999 non-null    object
#  9   insured_relationship         999 non-null    object
#  10  capital-gains                999 non-null    int64
#  11  capital-loss                 999 non-null    int64
#  12  incident_date                999 non-null    object
#  13  incident_type                999 non-null    object
#  14  collision_type               999 non-null    object
#  15  incident_severity            999 non-null    object
#  16  authorities_contacted        999 non-null    object
#  17  incident_hour_of_the_day     999 non-null    int64
#  18  number_of_vehicles_involved  999 non-null    int64
#  19  property_damage              999 non-null    object
#  20  bodily_injuries              999 non-null    int64
#  21  witnesses                    999 non-null    int64
#  22  police_report_available      999 non-null    object
#  23  total_claim_amount           999 non-null    int64
#  24  injury_claim                 999 non-null    int64
#  25  property_claim               999 non-null    int64
#  26  vehicle_claim                999 non-null    int64
#  27  fraud_reported               999 non-null    object
# dtypes: float64(1), int64(14), object(13)
# memory usage: 226.3+ KB

# %% [markdown]
# ### **2.3 Fix Data Types** <font color = red>[3 marks]</font>
# Carefully examine the dataset and identify columns that contain date or time information but are not stored as the appropriate data type. Convert these columns to the correct datetime data type to enable proper analysis and manipulation of temporal information.

# %%
# Fix the data types of the columns with incorrect data types
# df['fraud_reported'] = df['fraud_reported'].map({'Y': 1, 'N': 0})
df['incident_date'] = pd.to_datetime(df['incident_date'])

# %%
# Check the features of the data again
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, 0 to 999
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           999 non-null    int64
#  1   age                          999 non-null    int64
#  2   policy_csl                   999 non-null    object
#  3   policy_deductable            999 non-null    int64
#  4   policy_annual_premium        999 non-null    float64
#  5   umbrella_limit               999 non-null    int64
#  6   insured_sex                  999 non-null    object
#  7   insured_education_level      999 non-null    object
#  8   insured_occupation           999 non-null    object
#  9   insured_relationship         999 non-null    object
#  10  capital-gains                999 non-null    int64
#  11  capital-loss                 999 non-null    int64
#  12  incident_date                999 non-null    datetime64[ns]
#  13  incident_type                999 non-null    object
#  14  collision_type               999 non-null    object
#  15  incident_severity            999 non-null    object
#  16  authorities_contacted        999 non-null    object
#  17  incident_hour_of_the_day     999 non-null    int64
#  18  number_of_vehicles_involved  999 non-null    int64
#  19  property_damage              999 non-null    object
#  20  bodily_injuries              999 non-null    int64
#  21  witnesses                    999 non-null    int64
#  22  police_report_available      999 non-null    object
#  23  total_claim_amount           999 non-null    int64
#  24  injury_claim                 999 non-null    int64
#  25  property_claim               999 non-null    int64
#  26  vehicle_claim                999 non-null    int64
#  27  fraud_reported               999 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(14), object(12)
# memory usage: 226.3+ KB

# %%
df.head()
# Out:
#    months_as_customer  age policy_csl  policy_deductable  \
# 0                 328   48    250/500               1000
# 1                 228   42    250/500               2000
# 2                 134   29    100/300               2000
# 3                 256   41    250/500               2000
# 4                 228   44   500/1000               1000
#
#    policy_annual_premium  umbrella_limit insured_sex insured_education_level  \
# 0                1406.91               0        MALE                      MD
# 1                1197.22         5000000        MALE                      MD
# 2                1413.14         5000000      FEMALE                     PhD
# 3                1415.74         6000000      FEMALE                     PhD
# 4                1583.91         6000000        MALE               Associate
#
#   insured_occupation insured_relationship  capital-gains  capital-loss  \
# 0       craft-repair              husband          53300             0
# 1  machine-op-inspct       other-relative              0             0
# 2              sales            own-child          35100             0
# 3       armed-forces            unmarried          48900        -62400
# 4              sales            unmarried          66000        -46000
#
#   incident_date             incident_type   collision_type incident_severity  \
# 0    2015-01-25  Single Vehicle Collision   Side Collision      Major Damage
# 1    2015-01-21             Vehicle Theft          Unknown      Minor Damage
# 2    2015-02-22   Multi-vehicle Collision   Rear Collision      Minor Damage
# 3    2015-01-10  Single Vehicle Collision  Front Collision      Major Damage
# 4    2015-02-17             Vehicle Theft          Unknown      Minor Damage
#
#   authorities_contacted  incident_hour_of_the_day  \
# 0                Police                         5
# 1                Police                         8
# 2                Police                         7
# 3                Police                         5
# 4               Unknown                        20
#
#    number_of_vehicles_involved property_damage  bodily_injuries  witnesses  \
# 0                            1             YES                1          2
# 1                            1         Unknown                0          0
# 2                            3              NO                2          3
# 3                            1         Unknown                1          2
# 4                            1              NO                0          1
#
#   police_report_available  total_claim_amount  injury_claim  property_claim  \
# 0                     YES               71610          6510           13020
# 1                 Unknown                5070           780             780
# 2                      NO               34650          7700            3850
# 3                      NO               63400          6340            6340
# 4                      NO                6500          1300             650
#
#    vehicle_claim fraud_reported
# 0          52080              Y
# 1           3510              Y
# 2          23100              N
# 3          50720              Y
# 4           4550              N

# %% [markdown]
# ## **3. Train-Validation Split** <font color = red>[5 marks]</font>

# %% [markdown]
# ### **3.1 Import required libraries**

# %%
# Import train-test-split
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **3.2 Define feature and target variables** <font color = red>[2 Marks]</font>

# %%
# Put all the feature variables in X
X=df.drop(['fraud_reported'], axis=1)
# Put the target variable in y
y=df['fraud_reported']

# %%
X.shape
# Out:
# (999, 27)

# %%
y.shape
# Out:
# (999,)

# %% [markdown]
# ### **3.3 Split the data** <font color="red">[3 Marks]</font>

# %%
# Split the dataset into 70% train and 30% validation and use stratification on the target variable
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.3, random_state=42)

# Reset index for all train and test sets
X_train=X_train.reset_index(drop=True)
X_test=X_test.reset_index(drop=True)
y_train=y_train.reset_index(drop=True)
y_test=y_test.reset_index(drop=True)

# %%
X_train.head()
# Out:
#    months_as_customer  age policy_csl  policy_deductable  \
# 0                 243   41    100/300               1000
# 1                 147   37   500/1000               1000
# 2                 146   31    250/500               2000
# 3                 161   38    100/300               2000
# 4                 239   38    250/500               1000
#
#    policy_annual_premium  umbrella_limit insured_sex insured_education_level  \
# 0                1129.23               0      FEMALE                 College
# 1                1439.90         6000000      FEMALE               Associate
# 2                1082.72               0      FEMALE                     PhD
# 3                1133.85               0        MALE                     PhD
# 4                1276.73         5000000      FEMALE                 Masters
#
#   insured_occupation insured_relationship  capital-gains  capital-loss  \
# 0    farming-fishing            own-child          17300        -60400
# 1     prof-specialty              husband              0        -48400
# 2  machine-op-inspct        not-in-family          61400        -57500
# 3    priv-house-serv        not-in-family          60200             0
# 4  handlers-cleaners       other-relative              0             0
#
#   incident_date             incident_type   collision_type incident_severity  \
# 0    2015-02-23  Single Vehicle Collision  Front Collision      Major Damage
# 1    2015-01-29   Multi-vehicle Collision   Rear Collision        Total Loss
# 2    2015-01-15             Vehicle Theft          Unknown      Minor Damage
# 3    2015-01-03   Multi-vehicle Collision  Front Collision        Total Loss
# 4    2015-02-19   Multi-vehicle Collision  Front Collision      Major Damage
#
#   authorities_contacted  incident_hour_of_the_day  \
# 0                  Fire                         1
# 1                 Other                         2
# 2               Unknown                         3
# 3                Police                         0
# 4                Police                        12
#
#    number_of_vehicles_involved property_damage  bodily_injuries  witnesses  \
# 0                            1         Unknown                1          0
# 1                            2              NO                1          2
# 2                            1             YES                2          0
# 3                            3             YES                2          2
# 4                            3              NO                1          3
#
#   police_report_available  total_claim_amount  injury_claim  property_claim  \
# 0                     YES               50300         10060            5030
# 1                      NO               53680          9760            4880
# 2                      NO                5220           580             580
# 3                     YES               60480          5040           15120
# 4                 Unknown               61920          6880            6880
#
#    vehicle_claim
# 0          35210
# 1          39040
# 2           4060
# 3          40320
# 4          48160

# %% [markdown]
# ## **4. EDA on training data** <font color = red>[20 marks]</font>

# %% [markdown]
# ### **4.1 Perform univariate analysis** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **4.1.1** Identify and select numerical columns from training data for univariate analysis <font color = "red">[1 Mark]</font>

# %%
# Select numerical columns
numerical_cols=X_train.select_dtypes(include='number').columns
numerical_cols
# Out:
# Index(['months_as_customer', 'age', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'capital-gains',
#        'capital-loss', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'bodily_injuries', 'witnesses',
#        'total_claim_amount', 'injury_claim', 'property_claim',
#        'vehicle_claim'],
#       dtype='object')

# %% [markdown]
# #### **4.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics <font color = "red">[4 Marks]</font>

# %%
# Plot all the numerical columns to understand their distribution
for col in numerical_cols:
    fig,axes=plt.subplots(1,2, figsize=(12,3))
    
    sns.boxplot(data=X_train, y=col, ax=axes[0])
    axes[0].set_title(f'Boxplot of {col}')
    
    sns.histplot(data=X_train, x=col, ax=axes[1], kde=True)
    axes[1].set_title(f'Distribution of {col}')
    
    plt.tight_layout()
    plt.show()

# %%
df[numerical_cols].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,1])
# Out:
#        months_as_customer         age  policy_deductable  \
# count          999.000000  999.000000         999.000000
# mean           203.873874   38.944945        1136.636637
# std            115.142928    9.144354         611.839681
# min              0.000000   19.000000         500.000000
# 25%            115.500000   32.000000         500.000000
# 50%            199.000000   38.000000        1000.000000
# 75%            276.000000   44.000000        2000.000000
# 90%            371.000000   53.000000        2000.000000
# 95%            429.100000   57.000000        2000.000000
# 100%           479.000000   64.000000        2000.000000
# max            479.000000   64.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit  capital-gains   capital-loss  \
# count             999.000000    9.990000e+02     999.000000     999.000000
# mean             1256.323934    1.103103e+06   25151.251251  -26820.520521
# std               244.275843    2.297594e+06   27874.792269   28105.366259
# min               433.330000    0.000000e+00       0.000000 -111100.000000
# 25%              1089.185000    0.000000e+00       0.000000  -51500.000000
# 50%              1257.040000    0.000000e+00       0.000000  -24100.000000
# 75%              1415.710000    0.000000e+00   51050.000000       0.000000
# 90%              1565.018000    6.000000e+06   64440.000000       0.000000
# 95%              1653.567000    6.000000e+06   70630.000000       0.000000
# 100%             2047.590000    1.000000e+07  100500.000000       0.000000
# max              2047.590000    1.000000e+07  100500.000000       0.000000
#
#        incident_hour_of_the_day  number_of_vehicles_involved  bodily_injuries  \
# count                999.000000                   999.000000       999.000000
# mean                  11.642643                     1.839840         0.992993
# std                    6.954722                     1.019044         0.819936
# min                    0.000000                     1.000000         0.000000
# 25%                    6.000000                     1.000000         0.000000
# 50%                   12.000000                     1.000000         1.000000
# 75%                   17.000000                     3.000000         2.000000
# 90%                   21.000000                     3.000000         2.000000
# 95%                   23.000000                     3.000000         2.000000
# 100%                  23.000000                     4.000000         2.000000
# max                   23.000000                     4.000000         2.000000
#
#         witnesses  total_claim_amount  injury_claim  property_claim  \
# count  999.000000          999.000000    999.000000      999.000000
# mean     1.487487        52720.500501   7432.292292     7389.839840
# std      1.111785        26382.199299   4883.266266     4817.316312
# min      0.000000          100.000000      0.000000        0.000000
# 25%      1.000000        41775.000000   4290.000000     4440.000000
# 50%      1.000000        57970.000000   6770.000000     6750.000000
# 75%      2.000000        70550.000000  11310.000000    10870.000000
# 90%      3.000000        81264.000000  14380.000000    14140.000000
# 95%      3.000000        88238.000000  15664.000000    15540.000000
# 100%     3.000000       114920.000000  21450.000000    23670.000000
# max      3.000000       114920.000000  21450.000000    23670.000000
#
#        vehicle_claim
# count     999.000000
# mean    37898.368368
# std     18870.924206
# min        70.000000
# 25%     30275.000000
# 50%     42080.000000
# 75%     50775.000000
# 90%     58720.000000
# 95%     63009.000000
# 100%    79560.000000
# max     79560.000000

# %% [markdown]
# <span style="color:blue">We observed that umbrella_limit is imbalanced but might be legit to keep those values</span>

# %% [markdown]
# <span style="color:blue">Remaining columns are looks fine</span>

# %% [markdown]
# ### **4.2 Perform correlation analysis** <font color="red">[3 Marks]</font>

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns
train_corr = X_train.copy()

cols_to_use = list(numerical_cols)
corr_mat=train_corr[cols_to_use].corr()

# Plot Heatmap of the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(corr_mat, annot= True, cmap='coolwarm', fmt=".2f")
plt.suptitle('Correlation Map of Numerical Variables', fontweight='heavy', x=0.327, y=0.96, ha='left', fontsize=13, fontfamily='serif')
plt.show()

# %% [markdown]
# <span style="color:green">OBSERVATION: </br>
# 1. months_as_customer and age columns are higly correlated. We will drop age columns</br>
# 2. total_claim_amount, injury_claim, property_claim and vehicle_claim columns are having high correlation. We will drop total_claim_amount which is likely aggregate sum of others</br>
# </span>

# %% [markdown]
# ### **4.3 Check class balance** <font color="red">[2 Marks]</font>

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances using visualisation for better understanding.

# %%
# Plot a bar chart to check class balance
sns.countplot(x=y_train)
plt.title("Distribution of Target Variable (fraud_reported)")
plt.xlabel("Fraud Reported")
plt.ylabel("Count")
plt.xticks([0, 1], ['No', 'Yes'])
plt.show()

# %%
y_train.value_counts()
# Out:
# fraud_reported
# N    532
# Y    167
# Name: count, dtype: int64

# %% [markdown]
# <span style="color:green">OBSERVATION: </br>
# 1. No values are dominating the yes values</br>
# </span>

# %% [markdown]
# ### **4.4 Perform bivariate analysis** <font color="red">[10 Marks]</font>

# %% [markdown]
# #### **4.4.1** Target likelihood analysis for categorical variables. <font color="red">[5 Marks]</font>
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features
from IPython.display import display, Markdown
def generate_observation_markdown(col, size):
    obs = f"<span style='color:green'><b>OBSERVATION for {col}:</b><br/>"

    obs += f"category {col} show high likelihood of fraud than other {size-1} remaining categories.<br/>"

    obs += "</span>"
    return obs

def target_likelihood_analysis(df, cat_cols, target='fraud_reported'):
    index=1
    for cat_col in cat_cols:
        index=index+1
        grouped=df.groupby(by=[cat_col])[target].mean().sort_values(ascending=False)
        print(f'🟩 Target likelihood for categorical feature: {cat_col}')
        print(grouped)
        print('-'*40)

        grouped.plot(kind='bar', title=f'{cat_col} vs Target Likelihood', figsize=(8,4))
        plt.show()
        plt.tight_layout()
        plt.ylabel(f'P({target} = 1)')
        plt.close()
        
        # To print observation markdown text
        markdown_note=generate_observation_markdown(grouped.idxmax(), len(grouped))
        display(Markdown(markdown_note))
        print('*'*80)
        print('\n')

# %%
cat_cols=X_train.select_dtypes(include=['object']).columns
train_target= X_train.copy()
train_target['fraud_reported'] = y_train.map({'Y': 1, 'N': 0})
target_likelihood_analysis(train_target, cat_cols)
# Out:
# 🟩 Target likelihood for categorical feature: policy_csl
# policy_csl
# 100/300     0.258333
# 250/500     0.253061
# 500/1000    0.200935
# Name: fraud_reported, dtype: float64
# ----------------------------------------
# <span style='color:green'><b>OBSERVATION for 100/300:</b><br/>category 100/300 show high likelihood of fraud than other 2 remaining categories.<br/></span>
# ********************************************************************************
#
#
# 🟩 Target likelihood for categorical feature: insured_sex
# insured_sex
# FEMALE    0.243767
# MALE      0.233728
# Name: fraud_reported, dtype: float64
# ----------------------------------------
# <span style='color:green'><b>OBSERVATION for FEMALE:</b><br/>category FEMALE show high likelihood of fraud than other 1 remaining categories.<br/></span>
# ********************************************************************************
#
#
# 🟩 Target likelihood for categorical feature: insured_education_level
# insured_education_level
# College        0.290698
# JD             0.254386
# PhD            0.240000
# MD             0.238095
# High School    0.230088
# Masters        0.220000
# Associate      0.207547
# Name: fraud_reported, dtype: float64
# ----------------------------------------
# <span style='color:green'><b>OBSERVATION for College:</b><br/>category College show high likelihood of fraud than other 6 remaining categories.<br/></span>
# ********************************************************************************
#
#
# 🟩 Target likelihood for categorical feature: insured_occupation
# insured_occupation
# craft-repair         0.360000
# exec-managerial      0.345455
# farming-fishing      0.315789
# tech-support         0.283333
# transport-moving     0.261905
# sales                0.250000
# handlers-cleaners    0.243243
# machine-op-inspct    0.225352
# armed-forces         0.212766
# protective-serv      0.191489
# other-service        0.181818
# prof-specialty       0.175439
# adm-clerical         0.166667
# priv-house-serv      0.145833
# Name: fraud_reported, dtype: float64
# ----------------------------------------
# <span style='color:green'><b>OBSERVATION for craft-repair:</b><br/>category craft-repair show high likelihood of fraud than other 13 remaining categories.<br/></span>
# ********************************************************************************
#
#
# 🟩 Target likelihood for categorical feature: insured_relationship
# insured_relationship
# other-relative    0.296875
# wife              0.272727
# not-in-family     0.247863
# husband           0.221311
# unmarried         0.201923
# own-child         0.186441
# Name: fraud_reported, dtype: float64
# ----------------------------------------
# <span style='color:green'><b>OBSERVATION for other-relative:</b><br/>category other-relative show high likelihood of fraud than other 5 remaining categories.<br/></span>
# ********************************************************************************
#
#
# 🟩 Target likelihood for categorical feature: incident_type
# incident_type
# Single Vehicle Collision    0.298246
# Multi-vehicle Collision     0.254296
# Parked Car                  0.083333
# Vehicle Theft               0.047619
# Name: fraud_reported, dtype: float64
# ----------------------------------------
# <span style='color:green'><b>OBSERVATION for Single Vehicle Collision:</b><br/>category Single Vehicle Collision show high likelihood of fraud than other 3 remaining categories.<br/></span>
# ********************************************************************************
#
#
# 🟩 Target likelihood for categorical feature: collision_type
# collision_type
# Front Collision    0.293103
# Rear Collision     0.291866
# Side Collision     0.243523
# Unknown            0.065041
# Name: fraud_reported, dtype: float64
# ----------------------------------------
# <span style='color:green'><b>OBSERVATION for Front Collision:</b><br/>category Front Collision show high likelihood of fraud than other 3 remaining categories.<br/></span>
# ********************************************************************************
#
#
# 🟩 Target likelihood for categorical feature: incident_severity
# incident_severity
# Major Damage      0.607330
# Total Loss        0.137255
# Minor Damage      0.088710
# Trivial Damage    0.017857
# Name: fraud_reported, dtype: float64
# ----------------------------------------
# <span style='color:green'><b>OBSERVATION for Major Damage:</b><br/>category Major Damage show high likelihood of fraud than other 3 remaining categories.<br/></span>
# ********************************************************************************
#
#
# 🟩 Target likelihood for categorical feature: authorities_contacted
# authorities_contacted
# Ambulance    0.291045
# Other        0.283688
# Fire         0.267974
# Police       0.206731
# Unknown      0.063492
# Name: fraud_reported, dtype: float64
# ----------------------------------------
# <span style='color:green'><b>OBSERVATION for Ambulance:</b><br/>category Ambulance show high likelihood of fraud than other 4 remaining categories.<br/></span>
# ********************************************************************************
#
#
# 🟩 Target likelihood for categorical feature: property_damage
# property_damage
# Unknown    0.282869
# YES        0.239130
# NO         0.188073
# Name: fraud_reported, dtype: float64
# ----------------------------------------
# <span style='color:green'><b>OBSERVATION for Unknown:</b><br/>category Unknown show high likelihood of fraud than other 2 remaining categories.<br/></span>
# ********************************************************************************
#
#
# 🟩 Target likelihood for categorical feature: police_report_available
# police_report_available
# Unknown    0.258621
# NO         0.238095
# YES        0.218605
# Name: fraud_reported, dtype: float64
# ----------------------------------------
# <span style='color:green'><b>OBSERVATION for Unknown:</b><br/>category Unknown show high likelihood of fraud than other 2 remaining categories.<br/></span>
# ********************************************************************************

# %%
def analyze_and_plot_category_frequencies(df, cat_cols, threshold=0.01):
    for col in cat_cols:
        print(f"\n🟩 Column: {col}")
        value_counts=df[col].value_counts(normalize=True)*100
        
        for category, freq in value_counts.items():
            if freq < threshold * 100:
                print(f' -->{category}: {freq:.2f}% (RARE)')
            else:
                print(f' -->{category}: {freq:.2f}%')

        
        plt.figure(figsize=(10, 4))
        colors = ['orange' if freq < threshold * 100 else 'skyblue' for freq in value_counts.values]
        sns.barplot(x=value_counts.index, y=value_counts.values, palette=colors)
        plt.title(f'Category Frequency in "{col}"')
        plt.axhline(y=threshold * 100, color='red', linestyle='--', label=f'{threshold*100:.1f}% Threshold')
        plt.xticks(rotation=45, ha='right')
        plt.ylabel("Frequency (%)")
        plt.legend()
        plt.tight_layout()
        plt.show()

# %%
analyze_and_plot_category_frequencies(train_target, cat_cols, threshold=0.075)
# Out:
# 🟩 Column: policy_csl
#  -->250/500: 35.05%
#  -->100/300: 34.33%
#  -->500/1000: 30.62%
# 🟩 Column: insured_sex
#  -->FEMALE: 51.65%
#  -->MALE: 48.35%
# 🟩 Column: insured_education_level
#  -->JD: 16.31%
#  -->High School: 16.17%
#  -->Associate: 15.16%
#  -->MD: 15.02%
#  -->Masters: 14.31%
#  -->College: 12.30%
#  -->PhD: 10.73%
# 🟩 Column: insured_occupation
#  -->machine-op-inspct: 10.16%
#  -->tech-support: 8.58%
#  -->prof-specialty: 8.15%
#  -->other-service: 7.87%
#  -->exec-managerial: 7.87%
#  -->craft-repair: 7.15% (RARE)
#  -->priv-house-serv: 6.87% (RARE)
#  -->adm-clerical: 6.87% (RARE)
#  -->armed-forces: 6.72% (RARE)
#  -->protective-serv: 6.72% (RARE)
#  -->sales: 6.29% (RARE)
#  -->transport-moving: 6.01% (RARE)
#  -->farming-fishing: 5.44% (RARE)
#  -->handlers-cleaners: 5.29% (RARE)
# 🟩 Column: insured_relationship
#  -->other-relative: 18.31%
#  -->husband: 17.45%
#  -->own-child: 16.88%
#  -->not-in-family: 16.74%
#  -->wife: 15.74%
#  -->unmarried: 14.88%
# 🟩 Column: incident_type
#  -->Multi-vehicle Collision: 41.63%
#  -->Single Vehicle Collision: 40.77%
#  -->Vehicle Theft: 9.01%
#  -->Parked Car: 8.58%
# 🟩 Column: collision_type
#  -->Rear Collision: 29.90%
#  -->Side Collision: 27.61%
#  -->Front Collision: 24.89%
#  -->Unknown: 17.60%
# 🟩 Column: incident_severity
#  -->Minor Damage: 35.48%
#  -->Total Loss: 29.18%
#  -->Major Damage: 27.32%
#  -->Trivial Damage: 8.01%
# 🟩 Column: authorities_contacted
#  -->Police: 29.76%
#  -->Fire: 21.89%
#  -->Other: 20.17%
#  -->Ambulance: 19.17%
#  -->Unknown: 9.01%
# 🟩 Column: property_damage
#  -->Unknown: 35.91%
#  -->YES: 32.90%
#  -->NO: 31.19%
# 🟩 Column: police_report_available
#  -->NO: 36.05%
#  -->Unknown: 33.19%
#  -->YES: 30.76%

# %% [markdown]
# #### **4.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome using appropriate visualisation techniques to identify trends and potential interactions. <font color="red">[5 Marks]</font>

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome
def numerical_vs_target_analysis(df, num_cols, target='fraud_reported'):
    for col in num_cols:
        plt.figure(figsize=(8, 4))
        sns.boxplot(x=target, y=col, data=df)
        plt.title(f'{col} vs {target}')
        plt.xlabel('Fraud Reported (0 = No, 1 = Yes)')
        plt.ylabel(col)
        plt.tight_layout()
        plt.show()
        
numerical_cols=X_train.select_dtypes(include=['int', 'float']).columns
numerical_vs_target_analysis(train_target, numerical_cols)

# %% [markdown]
# ## **5. EDA on validation data** <font color = red>[OPTIONAL]</font>

# %% [markdown]
# ### **5.1 Perform univariate analysis**

# %% [markdown]
# #### **5.1.1** Identify and select numerical columns from training data for univariate analysis.

# %%
# Select numerical columns
numerical_cols=X_test.select_dtypes(include='number').columns
numerical_cols

# %% [markdown]
# #### **5.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics.

# %%
# Plot all the numerical columns to understand their distribution
for col in numerical_cols:
    fig,axes=plt.subplots(1,2, figsize=(12,3))
    
    sns.boxplot(data=X_test, y=col, ax=axes[0])
    axes[0].set_title(f'Boxplot of {col}')
    
    sns.histplot(data=X_test, x=col, ax=axes[1], kde=True)
    axes[1].set_title(f'Distribution of {col}')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### **5.2 Perform correlation analysis**

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns
test_corr = X_test.copy()

cols_to_use = list(numerical_cols)
corr_mat=test_corr[cols_to_use].corr()

# Plot Heatmap of the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(corr_mat, annot= True, cmap='coolwarm', fmt=".2f")
plt.suptitle('Correlation Map of Numerical Variables', fontweight='heavy', x=0.327, y=0.96, ha='left', fontsize=13, fontfamily='serif')
plt.show()

# %% [markdown]
# ### **5.3 Check class balance**

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances. Visualise the distribution for better understanding.

# %%
# Plot a bar chart to check class balance
sns.countplot(x=y_test)
plt.title("Distribution of Target Variable (fraud_reported)")
plt.xlabel("Fraud Reported")
plt.ylabel("Count")
plt.xticks([0, 1], ['No', 'Yes'])
plt.show()

# %% [markdown]
# ### **5.4 Perform bivariate analysis**

# %% [markdown]
# #### **5.4.1** Target likelihood analysis for categorical variables.
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features

# %% [markdown]
# #### **5.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome. Utilise appropriate visualisation techniques to identify trends and potential interactions.

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome
cat_cols=X_test.select_dtypes(include=['object']).columns
test_target= X_test.copy()
test_target['fraud_reported'] = y_test.map({'Y': 1, 'N': 0})
target_likelihood_analysis(test_target, cat_cols)

# %% [markdown]
# ## **6. Feature Engineering** <font color = red>[25 marks]</font>

# %% [markdown]
# ### **6.1 Perform resampling** <font color="red">[3 Marks]</font>

# %% [markdown]
# Handle class imbalance in the training data by applying resampling technique.
#
# Use the **RandomOverSampler** technique to balance the data and handle class imbalance. This method increases the number of samples in the minority class by randomly duplicating them, creating synthetic data points with similar characteristics. This helps prevent the model from being biased toward the majority class and improves its ability to predict the minority class more accurately.
#
# **Note:** You can try other resampling techniques to handle class imbalance

# %%
# Import RandomOverSampler from imblearn library
from imblearn.over_sampling import RandomOverSampler

# Perform resampling on training data
ros=RandomOverSampler(random_state=42)
X_train, y_train = ros.fit_resample(X_train, y_train)
y_train = pd.Series(y_train, name='fraud_reported')

# %%
print(f'Shape of sampling for X_train {X_train.shape}')

# %%
print(f'Shape of sampling for y_train {y_train.shape}')

# %% [markdown]
# ### **6.2 Feature Creation** <font color="red">[4 marks]</font>

# %% [markdown]
# Create new features from existing ones to enhance the model's ability to capture patterns in the data. This may involve deriving features from date/time columns, combining features, or creating interaction terms.

# %%
# Create new features based on your understanding for both training and validation data
def derive_incident_date_metrics(df):
    df['incident_year']=df['incident_date'].dt.year
    df['incident_month']=df['incident_date'].dt.month
    df['incident_day']=df['incident_date'].dt.day
    df['incident_day_of_week']=df['incident_date'].dt.dayofweek
    df['incident_week_of_year']=df['incident_date'].dt.isocalendar().week
    df['incident_year']=df['incident_date'].dt.quarter

# %%
derive_incident_date_metrics(X_train)
derive_incident_date_metrics(X_test)

# %%
print(f'Shape of X_train after adding the columns:{X_train.shape}')
print(f'Shape of X_test after adding the columns:{X_test.shape}')

# %% [markdown]
# ### **6.3 Handle redundant columns** <font color="red">[3 marks]</font>

# %% [markdown]
# Analyse the data to identify features that may be redundant or contribute minimal information toward predicting the target variable and drop them.
#
# - You can consider features that exhibit high correlation with other variables, which you may have observed during the EDA phase.
# - Features that don't strongly influence the prediction, which you may have observed during the EDA phase.
# - Categorical columns with low value counts for some levels can be remapped to reduce number of unique levels, and features with very high counts for just one level may be removed, as they resemble unique identifier columns and do not provide substantial predictive value.
# - Additionally, eliminate any columns from which the necessary features have already been extracted in the preceding step.

# %%
# Drop redundant columns from training and validation data

# age and total_claim_amount  are highly correlated fiels
# incident_date 
X_train.drop(['age', 'total_claim_amount', 'incident_date'], axis=1, inplace=True)
X_test.drop(['age', 'total_claim_amount', 'incident_date'], axis=1, inplace=True)

# %%
# Check the data
print(f'Shape of X_train after dropping the columns:{X_train.shape}')
print(f'Shape of X_test after dropping the columns:{X_test.shape}')

# %% [markdown]
# ### **6.4 Combine values in Categorical Columns** <font color="red">[6 Marks]</font>
# During the EDA process, categorical columns with multiple unique values may be identified. To enhance model performance, it is essential to refine these categorical features by grouping values that have low frequency or provide limited predictive information.
#
# Combine categories that occur infrequently or exhibit similar behavior to reduce sparsity and improve model generalisation.

# %%
# Combine categories that have low frequency or provide limited predictive information

# Combining Incident-type bottom two values as sum of top two values is giving more than 80%
X_train['incident_type'] = X_train['incident_type'].replace(['Vehicle Theft', 'Parked Car'], 'Low Risk Incident')

X_train['insured_occupation'] = X_train['insured_occupation'].apply(
    lambda x: x if x in ['machine-op-inspct', 'tech-support', 'prof-specialty', 'other-service', 'exec-managerial']
    else 'Other'
)

X_test['incident_type'] = X_test['incident_type'].replace(['Vehicle Theft', 'Parked Car'], 'Low Risk Incident')

X_test['insured_occupation'] = X_test['insured_occupation'].apply(
    lambda x: x if x in ['machine-op-inspct', 'tech-support', 'prof-specialty', 'other-service', 'exec-managerial']
    else 'Other'
)

# %%
print(f'incident_type value counts in train data \n{X_train['incident_type'].value_counts()}')
print('*'*20)
print(f'incident_type value counts in test data \n{X_test['incident_type'].value_counts()}')

# %%
print(f'insured_occupation value counts in train data \n{X_train['insured_occupation'].value_counts()}')
print('*'*20)
print(f'insured_occupation value counts in test data \n{X_test['insured_occupation'].value_counts()}')

# %% [markdown]
# ### **6.5 Dummy variable creation** <font color="red">[6 Marks]</font>
# Transform categorical variables into numerical representations using dummy variables. Ensure consistent encoding between training and validation data.

# %% [markdown]
# #### **6.5.1** Identify categorical columns for dummy variable creation <font color="red">[1 Mark]</font>

# %%
# Identify the categorical columns for creating dummy variables
categorical_cols = X_train.select_dtypes(include='object').columns.tolist()
print("Categorical columns:", categorical_cols)

# %% [markdown]
# #### **6.5.2** Create dummy variables for categorical columns in training data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in training data
X_train=pd.get_dummies(X_train, columns=categorical_cols, drop_first=True, dtype=int)
X_train.shape

# %% [markdown]
# #### **6.5.3** Create dummy variables for categorical columns in validation data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in validation data
X_test=pd.get_dummies(X_test, columns=categorical_cols, drop_first=True, dtype=int)
X_test.shape

# %%
X_train.head()

# %% [markdown]
# #### **6.5.4** Create dummy variable for dependent feature in training and validation data <font color = "red">[1 Mark]</font>

# %%
# Create dummy variable for dependent feature in training data
y_train = y_train.map({'Y': 1, 'N': 0})


# Create dummy variable for dependent feature in validation data
y_test = y_test.map({'Y': 1, 'N': 0})

# %%
y_train.head()

# %%
y_test.head()

# %% [markdown]
# ### **6.6 Feature scaling** <font color = red>[3 marks]</font>
# Scale numerical features to a common range to prevent features with larger values from dominating the model.  Choose a scaling method appropriate for the data and the chosen model. Apply the same scaling to both training and validation data.

# %%
# Import the necessary scaling tool from scikit-learn
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# Scale the numeric features present in the training data
X_train_scaled = scaler.fit_transform(X_train)

# Scale the numeric features present in the validation data
X_test_scaled = scaler.transform(X_test)

X_train = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %% [markdown]
# ## **7. Model Building** <font color = red>[50 marks]</font>

# %% [markdown]
# In this task, you will be building two machine learning models: Logistic Regression and Random Forest. Each model will go through a structured process to ensure optimal performance. The key steps for each model are outlined below:
#
# **Logistic Regression Model**
# - Feature Selection using RFECV – Identify the most relevant features using Recursive Feature Elimination with Cross-Validation.
# - Model Building and Multicollinearity Assessment – Build the logistic regression model and analyse statistical aspects such as p-values and VIFs to detect multicollinearity.
# - Model Training and Evaluation on Training Data – Fit the model on the training data and assess initial performance.
# - Finding the Optimal Cutoff – Determine the best probability threshold by analysing the sensitivity-specificity tradeoff and precision-recall tradeoff.
# - FInal Prediction and Evaluation on Training Data using the Optimal Cutoff – Generate final predictions using the selected cutoff and evaluate model performance.
#
# **Random Forest Model**
# - Get Feature Importances - Obtain the importance scores for each feature and select the important features to train the model.
# - Model Evaluation on Training Data – Assess performance metrics on the training data.
# - Check Model Overfitting using Cross-Validation – Evaluate generalisation by performing cross-validation.
# - Hyperparameter Tuning using Grid Search – Optimise model performance by fine-tuning hyperparameters.
# - Final Model and Evaluation on Training Data – Train the final model using the best parameters and assess its performance.

# %% [markdown]
# ### **7.1 Feature selection** <font color = red>[4 marks]</font>
# Identify and select the most relevant features for building a logistic regression model using Recursive Feature Elimination with Cross-Validation (RFECV).

# %% [markdown]
# #### **7.1.1** Import necessary libraries <font color="red">[1 Mark]</font>

# %%
# Import necessary libraries
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# #### **7.1.2** Perform feature selection <font color="red">[2 Mark]</font>

# %%
# Apply RFECV to identify the most relevant features
log_reg=LogisticRegression(random_state=42)
rfecv=RFECV(
   estimator=log_reg,
   step=1,
   cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=42),
   scoring='accuracy',
)
rfecv.fit(X_train, y_train)

# %%
# Display the features ranking by RFECV in a DataFrame
feature_ranks=pd.DataFrame({
    'Feature': X_train.columns,
    'Rank': rfecv.ranking_,
    'Selected': rfecv.support_
}).sort_values(by='Rank')
feature_ranks

# %% [markdown]
# #### **7.1.2** Retain the selected features <font color="red">[1 Mark]</font>

# %%
# Put columns selected by RFECV into variable 'col'
col=X_train.columns[rfecv.support_].tolist()
print(f'list of columns {col}')

# %% [markdown]
# ### **7.2 Build Logistic Regression Model** <font color = red>[12 marks]</font>
# After selecting the optimal features using RFECV, utilise these features to build a logistic regression model with Statsmodels. This approach enables a detailed statistical analysis of the model, including the assessment of p-values and Variance Inflation Factors (VIFs). Evaluating these metrics is crucial for detecting multicollinearity and ensuring that the selected predictors are not highly correlated.

# %% [markdown]
# #### **7.2.1** Select relevant features and add constant in training data <font color="red">[1 Mark]</font>

# %%
# Select only the columns selected by RFECV
X_train_selected=X_train[col]
X_train_selected.head()

# %%
# Import statsmodels and add constant
import statsmodels.api as sm
X_train_selected_constant=sm.add_constant(X_train_selected)
# Check the data
X_train_selected_constant.head()

# %% [markdown]
# #### **7.2.2** Fit logistic regression model <font color="red">[2 Marks]</font>

# %%
# Fit a logistic Regression model on X_train after adding a constant and output the summary
X_train_selected_constant=X_train_selected_constant.astype('float64')
logm1 = sm.GLM(y_train, X_train_selected_constant, family = sm.families.Binomial())
logm1.fit().summary()

# %% [markdown]
# **Model Interpretation**
#
# The output summary table will provide the features used for building model along with coefficient of each of the feature and their p-value. The p-value in a logistic regression model is used to assess the statistical significance of each coefficient. Lesser the p-value, more significant the feature is in the model.
#
# A positive coefficient will indicate that an increase in the value of feature would increase the odds of the event occurring. On the other hand, a negative coefficient means the opposite, i.e, an increase in the value of feature would decrease the odds of the event occurring.

# %% [markdown]
# Now check VIFs for presence of multicollinearity in the model.

# %% [markdown]
# #### **7.2.3** Evaluate VIF of features to assess multicollinearity <font color="red">[2 Marks]</font>

# %%
# Import 'variance_inflation_factor'
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Make a VIF DataFrame for all the variables present
def calculateVIF(df):
    vif = pd.DataFrame()
    vif['Features'] = df.columns
    vif['VIF'] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
    vif['VIF'] = round(vif['VIF'], 2)
    vif = vif.sort_values(by = "VIF", ascending = False)
    return vif

# %%
calculateVIF(X_train_selected_constant)

# %% [markdown]
# Proceed to the next step if p-values and VIFs are within acceptable ranges. If you observe high p-values or VIFs, drop the features and retrain the model. <font color="red">[THIS IS OPTIONAL]</font>

# %%
# dropping the incident_type_Multi-vehicle Collision as it is having vif of 30.09 and  p-value of 0.83
X_train_selected=X_train_selected.drop(["incident_type_Multi-vehicle Collision"], axis=1)
X_train_selected_constant=sm.add_constant(X_train_selected)
X_train_selected_constant=X_train_selected_constant.astype('float64')
logm2 = sm.GLM(y_train, X_train_selected_constant, family = sm.families.Binomial())
logm2.fit().summary()

# %%
calculateVIF(X_train_selected_constant)

# %%
# dropping the incident_type_Single Vehicle Collision as it is having vif of 6.74 and p-value of 0.274
X_train_selected=X_train_selected.drop(["incident_type_Single Vehicle Collision"], axis=1)
X_train_selected_constant=sm.add_constant(X_train_selected)
X_train_selected_constant=X_train_selected_constant.astype('float64')
logm3 = sm.GLM(y_train, X_train_selected_constant, family = sm.families.Binomial())
logm3.fit().summary()

# %%
calculateVIF(X_train_selected_constant)

# %%
# dropping the number_of_vehicles_involved as it is having p-value of 0.102
X_train_selected=X_train_selected.drop(["number_of_vehicles_involved"], axis=1)
X_train_selected_constant=sm.add_constant(X_train_selected)
X_train_selected_constant=X_train_selected_constant.astype('float64')
logm4 = sm.GLM(y_train, X_train_selected_constant, family = sm.families.Binomial())
logm4.fit().summary()

# %%
calculateVIF(X_train_selected_constant)

# %%
# dropping the insured_relationship_not-in-family as it is having p-value of 0.073
X_train_selected=X_train_selected.drop(["insured_relationship_not-in-family"], axis=1)
X_train_selected_constant=sm.add_constant(X_train_selected)
X_train_selected_constant=X_train_selected_constant.astype('float64')
logm5 = sm.GLM(y_train, X_train_selected_constant, family = sm.families.Binomial())
logm5.fit().summary()

# %%
calculateVIF(X_train_selected_constant)

# %%
# dropping the insured_relationship_other-relative as it is having p-value of 0.214
X_train_selected=X_train_selected.drop(["insured_relationship_other-relative"], axis=1)
X_train_selected_constant=sm.add_constant(X_train_selected)
X_train_selected_constant=X_train_selected_constant.astype('float64')
logm6 = sm.GLM(y_train, X_train_selected_constant, family = sm.families.Binomial())
logm6.fit().summary()

# %%
calculateVIF(X_train_selected_constant)

# %%
# dropping the insured_relationship_wife as it is having p-value of 0.151	
X_train_selected=X_train_selected.drop(["insured_relationship_wife"], axis=1)
X_train_selected_constant=sm.add_constant(X_train_selected)
X_train_selected_constant=X_train_selected_constant.astype('float64')
logm7 = sm.GLM(y_train, X_train_selected_constant, family = sm.families.Binomial())
logm7.fit().summary()

# %%
calculateVIF(X_train_selected_constant)

# %%
# dropping the policy_annual_premium as it is having p-value of 0.066
X_train_selected=X_train_selected.drop(["policy_annual_premium"], axis=1)
X_train_selected_constant=sm.add_constant(X_train_selected)
X_train_selected_constant=X_train_selected_constant.astype('float64')
logm8 = sm.GLM(y_train, X_train_selected_constant, family = sm.families.Binomial())
logm8.fit().summary()

# %%
calculateVIF(X_train_selected_constant)

# %% [markdown]
# #### **7.2.4** Make predictions on training data <font color = "red">[1 Mark]</font>

# %%
# Predict the probabilities on the training data
result=logm8.fit()
y_pred_train = result.predict(X_train_selected_constant)
# Reshape it into an array
y_pred_array = y_pred_train.values.reshape(-1, 1)

# %% [markdown]
# #### **7.2.5** Create a DataFrame that includes actual fraud reported flags, predicted probabilities, and a column indicating predicted classifications based on a cutoff value of 0.5 <font color="red">[1 Mark]</font>

# %%
# Create a new DataFrame containing the actual fraud reported flag and the probabilities predicted by the model
df_prediction = pd.DataFrame({
    'actual': y_train.values,
    'predicted_prob': y_pred_array.flatten(),
})

# Create new column indicating predicted classifications based on a cutoff value of 0.5
y_pred_class=(y_pred_array>=0.5).astype(int)
df_prediction['predicted_class']=y_pred_class
df_prediction.head()

# %% [markdown]
# **Model performance evaluation**
#
# Evaluate the performance of the model based on predictions made on the training data.

# %% [markdown]
# #### **7.2.6** Check the accuracy of the model <font color = "red">[1 Mark]</font>

# %%
# Import metrics from sklearn for evaluation
from sklearn import metrics

# Check the accuracy of the model
metrics.accuracy_score(y_train, y_pred_class)

# %% [markdown]
# #### **7.2.7** Create a confusion matrix based on the predictions made on the training data <font color="red">[1 Mark]</font>

# %%
# Create confusion matrix
conf_mat=metrics.confusion_matrix(y_train, y_pred_class)

# %% [markdown]
# #### **7.2.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = conf_mat.ravel()

# %% [markdown]
# #### **7.2.9** Calculate sensitivity, specificity, precision, recall and F1-score <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity=tp/(tp+fn)
print(f'Sensitivity: {sensitivity}')

# Calculate the specificity
specificity=tn/(tn+fp)
print(f'Specificity: {specificity}')

# Calculate Precision
precision=tp/(tp+fp)
print(f'Precision: {precision}')

# Calculate Recall
recall=sensitivity
print(f'Rcall: {recall}')

# Calculate F1 Score
f1_score=2 * (precision*recall)/(precision+recall)
print(f'F1_score: {f1_score}')

# %% [markdown]
# ### **7.3 Find the Optimal Cutoff** <font color = red>[12 marks]</font>
# Find the optimal cutoff to improve model performance by evaluating various cutoff values and their impact on relevant metrics.

# %% [markdown]
# #### **7.3.1** Plot ROC Curve  to visualise the trade-off between true positive rate and false positive rate across different classification thresholds <font color="red">[2 Marks]</font>

# %%
# Import libraries or function to plot the ROC curve
from sklearn.metrics import roc_curve, roc_auc_score

# Define ROC function
def draw_roc( actual, probs ):
    fpr, tpr, thresholds = metrics.roc_curve( actual, probs,
                                              drop_intermediate = False )
    auc_score = metrics.roc_auc_score( actual, probs )
    plt.figure(figsize=(6, 6))
    plt.plot( fpr, tpr, label='ROC curve (area = %0.2f)' % auc_score )
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

    return fpr, tpr, thresholds

# %%
# Call the ROC function
draw_roc(y_train, y_pred_array)

# %% [markdown]
# **Sensitivity and Specificity tradeoff**
#
# After analysing the area under the curve of the ROC, check the sensitivity and specificity tradeoff to find the optimal cutoff point.

# %% [markdown]
# #### **7.3.2** Predict on training data at various probability cutoffs <font color="red">[1 Mark]</font>

# %%
# Create columns with different probability cutoffs to explore the impact of cutoff on model performance
cutoff_data = []

cutoffs = np.arange(0.1, 0.91, 0.05)
for cutoff in cutoffs:
    predicted = (y_pred_array >= cutoff).astype(int)
    tn, fp, fn, tp = metrics.confusion_matrix(y_train, predicted).ravel()
    
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)

    cutoff_data.append([cutoff, round(accuracy, 4), round(sensitivity, 4), round(specificity, 4)])

# %% [markdown]
# #### **7.3.3** Plot accuracy, sensitivity, specificity at different values of probability cutoffs <font color="red">[2 Marks]</font>

# %%
# Create a DataFrame to see the values of accuracy, sensitivity, and specificity at different values of probability cutoffs
df_cutoffs = pd.DataFrame(cutoff_data, columns=['cutoff', 'accuracy', 'sensitivity', 'specificity'])
df_cutoffs

# %%
# Plot accuracy, sensitivity, and specificity at different values of probability cutoffs
plt.figure(figsize=(10, 6))
plt.plot(df_cutoffs['cutoff'], df_cutoffs['accuracy'], label='Accuracy', marker='o')
plt.plot(df_cutoffs['cutoff'], df_cutoffs['sensitivity'], label='Sensitivity', marker='o')
plt.plot(df_cutoffs['cutoff'], df_cutoffs['specificity'], label='Specificity', marker='o')

plt.xlabel('Probability Cutoff')
plt.ylabel('Score')
plt.title('Model Performance Metrics vs Cutoff')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### **7.3.4** Create a column for final prediction based on optimal cutoff <font color="red">[1 Mark]</font>

# %%
# Create a column for final prediction based on the optimal cutoff
df_prediction['final_pred_0.4']=(df_prediction['predicted_prob'] >= 0.48).astype(int)

# %% [markdown]
# #### **7.3.5** Calculate the accuracy <font color="red">[1 Mark]</font>

# %%
# Check the accuracy now
optimal_accuracy=metrics.accuracy_score(df_prediction['actual'], df_prediction['final_pred_0.4'])
print(f'Optimal accuracy is {optimal_accuracy}')

# %% [markdown]
# #### **7.3.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix once again
optimal_conf_mat=metrics.confusion_matrix(df_prediction['actual'], df_prediction['final_pred_0.4'])
optimal_conf_mat

# %% [markdown]
# #### **7.3.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = optimal_conf_mat.ravel()

# %% [markdown]
# #### **7.3.8** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Mark]</font>

# %%
# Calculate the sensitivity
sensitivity=tp/(tp+fn)
print(f'Optimal Sensitivity: {sensitivity}')

# Calculate the specificity
specificity=tn/(tn+fp)
print(f'Optimal Specificity: {specificity}')

# Calculate Precision
precision=tp/(tp+fp)
print(f'Optimal Precision: {precision}')

# Calculate Recall
recall=sensitivity
print(f'Optimal Rcall: {recall}')

# Calculate F1 Score
f1_score=2 * (precision*recall)/(precision+recall)
print(f'Optimal F1_score: {f1_score}')

# %% [markdown]
# **Precision and Recall tradeoff**
#
# Check optimal cutoff value by plotting precision-recall curve, and adjust the cutoff based on precision and recall tradeoff if required.

# %%
# Import precision-recall curve function
from sklearn.metrics import precision_recall_curve, average_precision_score

# %% [markdown]
# #### **7.3.9** Plot precision-recall curve <font color="red">[1 Mark]</font>

# %%
# Plot precision-recall curve
precision, recall, thresholds = precision_recall_curve(df_prediction['actual'], df_prediction['predicted_prob'])

avg_precision = average_precision_score(df_prediction['actual'], df_prediction['predicted_prob'])

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.', label=f'PR Curve (AP = {avg_precision:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### **7.4 Build Random Forest Model** <font color = red>[12 marks]</font>
# Now that you have built a logistic regression model, let's move on to building a random forest model.

# %% [markdown]
# #### **7.4.1** Import necessary libraries

# %%
# Import necessary libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score, GridSearchCV

# %% [markdown]
# #### **7.4.2** Build the random forest model <font color="red">[1 Mark]</font>

# %%
# Build a base random forest model
rf=RandomForestClassifier(random_state=42)
rf=rf.fit(X_train, y_train)

# %% [markdown]
# #### **7.4.3** Get feature importance scores and select important features <font color="red">[2 Marks]</font>

# %%
# Get feature importance scores from the trained model
importances=rf.feature_importances_

# Create a DataFrame to visualise the importance scores
feature_importances_df=pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)
feature_importances_df

# %%
# Select features with high importance 
important_features=feature_importances_df[feature_importances_df['Importance'] >= 0.01]['Feature']
important_features=important_features.to_list()
print(f'Important features {important_features}')
# Create a new training data with only the selected features
X_train_rf=X_train[important_features]

# %%
X_train_rf.head()

# %% [markdown]
# #### **7.4.4** Train the model with selected features <font color="red">[1 Mark]</font>

# %%
# Fit the model on the training data with selected features
rf_selected=rf.fit(X_train_rf, y_train)

# %% [markdown]
# #### **7.4.5** Generate predictions on the training data <font color="red">[1 Mark]</font>

# %%
# Generate predictions on training data
y_pred_train=rf_selected.predict(X_train_rf)

# %% [markdown]
# #### **7.4.6** Check accuracy of the model <font color="red">[1 Mark]</font>

# %%
# Check accuracy of the model
accuracy = metrics.accuracy_score(y_train, y_pred_train)
print("Training Accuracy:", round(accuracy, 4))

# %% [markdown]
# #### **7.4.7** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix to visualise the performance
conf_mat_rf=metrics.confusion_matrix(y_train, y_pred_train)
conf_mat_rf

# %% [markdown]
# #### **7.4.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = conf_mat.ravel()

# %% [markdown]
# #### **7.4.9** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity=tp/(tp+fn)
print(f'Random Forest Sensitivity: {sensitivity}')

# Calculate the specificity
specificity=tn/(tn+fp)
print(f'Random Forest Specificity: {specificity}')

# Calculate Precision
precision=tp/(tp+fp)
print(f'Random Forest Precision: {precision}')

# Calculate Recall
recall=sensitivity
print(f'Random Forest Rcall: {recall}')

# Calculate F1 Score
f1_score=2 * (precision*recall)/(precision+recall)
print(f'Random Forest F1_score: {f1_score}')

# %% [markdown]
# #### **7.4.10** Check if the model is overfitting training data using cross validation <font color = "red">[2 marks]</font>

# %%
# Use cross validation to check if the model is overfitting
cv_scores = cross_val_score(rf_selected, X_train_rf, y_train, cv=5, scoring='accuracy')

print("Cross-validation scores:", cv_scores)
print("Mean CV accuracy:", round(cv_scores.mean(), 4))
print("Std deviation:", round(cv_scores.std(), 4))

# %% [markdown]
# <span style="color:green">OBSERVATION: </br>
# 1. Mild sign of overfitting</br>
# </span>

# %% [markdown]
# ### **7.5 Hyperparameter Tuning** <font color = red>[10 Marks]</font>
#  Enhance the performance of the random forest model by systematically exploring and selecting optimal hyperparameter values using grid search.

# %% [markdown]
# #### **7.5.1** Use grid search to find the best hyperparameter values <font color = red>[2 Marks]</font>

# %%
# Use grid search to find the best hyperparamter values
param_grid={
    'max_depth': [2, 3, 5, 10, 20],
    'min_samples_leaf': [5, 10, 20, 50, 100],
    'criterion': ["gini", "entropy"]
}

grid_search = GridSearchCV(
    estimator=rf_selected,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    verbose=2
)
grid_search.fit(X_train_rf, y_train)
# Best Hyperparameters
print("*"*40)
print("\nBest Parameters:", grid_search.best_params_)

# %%
print("Best Parameters:", grid_search.best_params_)

# %% [markdown]
# #### **7.5.2** Build a random forest model based on hyperparameter tuning results <font color = red>[1 Mark]</font>

# %%
# Building random forest model based on results of hyperparameter tuning
rf_best=grid_search.best_estimator_

# %% [markdown]
# #### **7.5.3** Make predictions on training data <font color = red>[1 Mark]</font>

# %%
# Make predictions on training data
y_train_pred=rf_best.predict(X_train_rf)

# %% [markdown]
# #### **7.5.4** Check accuracy of Random Forest Model <font color = red>[1 Mark]</font>

# %%
# Check the accuracy
accuracy = metrics.accuracy_score(y_train, y_train_pred)
print("Training Accuracy for best parameters:", round(accuracy, 4))

# %% [markdown]
# #### **7.5.5** Create confusion matrix <font color = red>[1 Mark]</font>

# %%
# Create the confusion matrix
conf_mat_rf=metrics.confusion_matrix(y_train, y_train_pred)
conf_mat_rf

# %% [markdown]
# #### **7.5.6** Create variables for true positive, true negative, false positive and false negative <font color = red>[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = conf_mat.ravel()

# %% [markdown]
# #### **7.5.7** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color = red>[3 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity=tp/(tp+fn)
print(f'Random Forest Sensitivity: {sensitivity}')

# Calculate the specificity
specificity=tn/(tn+fp)
print(f'Random Forest Specificity: {specificity}')

# Calculate Precision
precision=tp/(tp+fp)
print(f'Random Forest Precision: {precision}')

# Calculate Recall
recall=sensitivity
print(f'Random Forest Rcall: {recall}')

# Calculate F1 Score
f1_score=2 * (precision*recall)/(precision+recall)
print(f'Random Forest F1_score: {f1_score}')

# %% [markdown]
# ## **8. Prediction and Model Evaluation** <font color = red>[20 marks]</font>
# Use the model from the previous step to make predictions on the validation data with the optimal cutoff. Then evaluate the model's performance using metrics such as accuracy, sensitivity, specificity, precision, and recall.

# %% [markdown]
# ### **8.1 Make predictions over validation data using logistic regression model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.1.1** Select relevant features for validation data and add constant <font color="red">[1 Mark]</font>

# %%
# Select the relevant features for validation data

# Add constant to X_validation

# %% [markdown]
# #### **8.1.2** Make predictions over validation data <font color="red">[1 Mark]</font>

# %%
# Make predictions on the validation data and store it in the variable 'y_validation_pred'

# %% [markdown]
# #### **8.1.3** Create DataFrame with actual values and predicted values for validation data <font color="red">[2 Marks]</font>

# %%
#  Create DataFrame with actual values and predicted values for validation data

# %% [markdown]
# #### **8.1.4** Make final prediction based on cutoff value <font color="red">[1 Mark]</font>

# %%
# Make final predictions on the validation data using the optimal cutoff

# %% [markdown]
# #### **8.1.5** Check the accuracy of logistic regression model on validation data <font color="red">[1 Mark]</font>

# %%
# Check the accuracy

# %% [markdown]
# #### **8.1.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix

# %% [markdown]
# #### **8.1.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative

# %% [markdown]
# #### **8.1.8** Calculate sensitivity, specificity, precision, recall and f1 score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity


# Calculate the specificity


# Calculate Precision


# Calculate Recall


# Calculate F1 Score

# %% [markdown]
# ### **8.2 Make predictions over validation data using random forest model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.2.1** Select the important features and make predictions over validation data <font color="red">[2 Marks]</font>

# %%
# Select the relevant features for validation data

# Make predictions on the validation data

# %% [markdown]
# #### **8.2.2** Check accuracy of random forest model <font color="red">[1 Mark]</font>

# %%
# Check accuracy

# %% [markdown]
# #### **8.2.3** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix

# %% [markdown]
# #### **8.2.4** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative

# %% [markdown]
# #### **8.2.5** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[5 Marks]</font>

# %%
# Calculate Sensitivity


# Calculate Specificity


# Calculate Precision


# Calculate Recall


# Calculate F1-score

# %% [markdown]
# ## **Evaluation and Conclusion**
# Write the conclusion.
